# %% [markdown]
# # The Chat Format
#
# In this notebook, you will explore how you can utilize the chat format to have extended conversations with chatbots personalized or specialized for specific tasks or behaviors.
#
# ## Setup

# %%
import os
import openai
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo", temperature = 0):
    messages = [{"role": "user", "content": prompt}]
    for i in range(10):
        try:
            response = openai.ChatCompletion.create(
                model=model,
                messages=messages,
                temperature=temperature # This is the degree of randomness of the model' output
            )
            return response.choices[0].message["content"]
        except Exception as e:
            time.sleep(1)
    raise e
    
def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    for i in range(10):
        try:
            response = openai.ChatCompletion.create(
                model=model,
                messages=messages,
                temperature=temperature, # this is the degree of randomness of the model's output
            )
            return response.choices[0].message["content"]
        except Exception as e:
                time.sleep(1)
    raise e

# %%
messages =  [  
    {'role':'system', 'content':'You are an assistant that speaks like Shakespeare.'},    
    {'role':'user', 'content':'tell me a joke'},   
    {'role':'assistant', 'content':'Why did the chicken cross the road'},   
    {'role':'user', 'content':'I don\'t know'}
]

# %%
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# To get to the other side! Thou should'st know this joke!

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},    
{'role':'user', 'content':'Hi, my name is Isa'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Hello Isa! Nice to meet you. How can I assist you today?

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},    
{'role':'user', 'content':'Yes,  can you remind me, What is my name?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# I'm sorry, but I don't have access to that information. Can you please let me know your name?

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},
{'role':'user', 'content':'Hi, my name is Isa'},
{'role':'assistant', 'content': "Hi Isa! It's nice to meet you. \
Is there anything I can help you with today?"},
{'role':'user', 'content':'Yes, you can remind me, What is my name?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Your name is Isa! How are you feeling today, Isa? Is there anything on your mind that you'd like to talk about?

# %% [markdown]
# # OrderBot
# We can automate the collection of user prompts and assistant responses to build a  OrderBot. The OrderBot will take orders at a pizza restaurant.

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, style={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
# !pip install panel
# Out:
# Collecting panel
#   Downloading panel-0.14.4-py2.py3-none-any.whl (20.8 MB)
#                                               0.0/20.8 MB ? eta -:--:--
#                                               0.1/20.8 MB 3.3 MB/s eta 0:00:07
#                                               0.3/20.8 MB 3.2 MB/s eta 0:00:07
#                                               0.4/20.8 MB 3.0 MB/s eta 0:00:07
#      -                                        0.5/20.8 MB 3.0 MB/s eta 0:00:07
MB 3.0 MB/s eta 0:00:01
#      ----------------------------------       16.1/18.5 MB 3.0 MB/s eta 0:00:01
#      -----------------------------------      16.2/18.5 MB 3.0 MB/s eta 0:00:01
#      -----------------------------------      16.4/18.5 MB 2.9 MB/s eta 0:00:01
#      -----------------------------------      16.5/18.5 MB 3.0 MB/s eta 0:00:01
#      -----------------------------------      16.6/18.5 MB 2.9 MB/s eta 0:00:01
#      ------------------------------------     16.8/18.5 MB 3.0 MB/s eta 0:00:01
#      ------------------------------------     16.9/18.5 MB 2.9 MB/s eta 0:00:01
#      ------------------------------------     17.0/18.5 MB 3.0 MB/s eta 0:00:01
#      -------------------------------------    17.2/18.5 MB 2.9 MB/s eta 0:00:01
#      -------------------------------------    17.3/18.5 MB 2.9 MB/s eta 0:00:01
#      -------------------------------------    17.4/18.5 MB 2.9 MB/s eta 0:00:01
#      -------------------------------------    17.6/18.5 MB 2.9 MB/s eta 0:00:01
#      --------------------------------------   17.7/18.5 MB 2.9 MB/s eta 0:00:01
#      --------------------------------------   17.8/18.5 MB 2.9 MB/s eta 0:00:01
#      --------------------------------------   18.0/18.5 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  18.1/18.5 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  18.2/18.5 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  18.4/18.5 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  18.5/18.5 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  18.5/18.5 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------- 18.5/18.5 MB 2.9 MB/s eta 0:00:00
# Collecting param>=1.12.0 (from panel)
#   Downloading param-1.13.0-py2.py3-none-any.whl (87 kB)
#                                               0.0/87.3 kB ? eta -:--:--
#      -------------------------------------    81.9/87.3 kB 4.5 MB/s eta 0:00:01
#      ---------------------------------------- 87.3/87.3 kB 1.6 MB/s eta 0:00:00
# Collecting pyviz-comms>=0.7.4 (from panel)
#   Downloading pyviz_comms-2.2.1-py2.py3-none-any.whl (42 kB)
#                                               0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 42.9/42.9 kB 2.0 MB/s eta 0:00:00
# Collecting markdown (from panel)
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#                                               0.0/93.9 kB ? eta -:--:--
#      ---------------------------------------  92.2/93.9 kB 5.1 MB/s eta 0:00:01
#      ---------------------------------------- 93.9/93.9 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\penvs\llm\lib\site-packages (from panel) (2.30.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\penvs\llm\lib\site-packages (from panel) (4.65.0)
# Collecting pyct>=0.4.4 (from panel)
#   Downloading pyct-0.5.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: bleach in c:\penvs\llm\lib\site-packages (from panel) (6.0.0)
# Requirement already satisfied: setuptools>=42 in c:\penvs\llm\lib\site-packages (from panel) (67.6.1)
# Requirement already satisfied: typing-extensions in c:\penvs\llm\lib\site-packages (from panel) (4.5.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\penvs\llm\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (3.1.2)
# Collecting numpy>=1.11.3 (from bokeh<2.5.0,>=2.4.0->panel)
#   Downloading numpy-1.24.3-cp39-cp39-win_amd64.whl (14.9 MB)
#                                               0.0/14.9 MB ? eta -:--:--
#                                               0.2/14.9 MB 5.9 MB/s eta 0:00:03
#                                               0.3/14.9 MB 4.2 MB/s eta 0:00:04
#      -                                        0.5/14.9 MB 3.7 MB/s eta 0:00:04
#      -                                        0.6/14.9 MB 3.5 MB/s eta 0:00:05
#      --                                       0.8/14.9 MB 3.4 MB/s eta 0:00:05
#      --                                       0.9/14.9 MB 3.3 MB/s eta 0:00:05
#      --                                       1.0/14.9 MB 3.2 MB/s eta 0:00:05
#      ---                                      1.2/14.9 MB 3.2 MB/s eta 0:00:05
#      ---                                      1.3/14.9 MB 3.2 MB/s eta 0:00:05
#      ---                                      1.4/14.9 MB 3.1 MB/s eta 0:00:05
#      ----                                     1.6/14.9 MB 3.1 MB/s eta 0:00:05
#      ----                                     1.7/14.9 MB 3.1 MB/s eta 0:00:05
MB 2.9 MB/s eta 0:00:01
#      -------------------------------------    13.9/14.9 MB 2.9 MB/s eta 0:00:01
#      -------------------------------------    14.0/14.9 MB 2.9 MB/s eta 0:00:01
#      --------------------------------------   14.1/14.9 MB 2.9 MB/s eta 0:00:01
#      --------------------------------------   14.3/14.9 MB 2.9 MB/s eta 0:00:01
#      --------------------------------------   14.4/14.9 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  14.5/14.9 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  14.7/14.9 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  14.8/14.9 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  14.9/14.9 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  14.9/14.9 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------- 14.9/14.9 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=16.8 in c:\penvs\llm\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (23.1)
# Collecting pillow>=7.1.0 (from bokeh<2.5.0,>=2.4.0->panel)
#   Downloading Pillow-9.5.0-cp39-cp39-win_amd64.whl (2.5 MB)
#                                               0.0/2.5 MB ? eta -:--:--
#      -                                        0.1/2.5 MB 3.6 MB/s eta 0:00:01
#      ----                                     0.3/2.5 MB 3.2 MB/s eta 0:00:01
#      ------                                   0.4/2.5 MB 3.1 MB/s eta 0:00:01
#      --------                                 0.5/2.5 MB 3.1 MB/s eta 0:00:01
#      ----------                               0.7/2.5 MB 3.0 MB/s eta 0:00:01
#      ------------                             0.8/2.5 MB 3.0 MB/s eta 0:00:01
#      ---------------                          1.0/2.5 MB 3.0 MB/s eta 0:00:01
#      -----------------                        1.1/2.5 MB 3.0 MB/s eta 0:00:01
#      -------------------                      1.2/2.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------                    1.4/2.5 MB 3.0 MB/s eta 0:00:01
#      -----------------------                  1.5/2.5 MB 3.0 MB/s eta 0:00:01
#      -------------------------                1.6/2.5 MB 3.0 MB/s eta 0:00:01
#      ----------------------------             1.8/2.5 MB 3.0 MB/s eta 0:00:01
#      ------------------------------           1.9/2.5 MB 3.0 MB/s eta 0:00:01
#      --------------------------------         2.1/2.5 MB 3.0 MB/s eta 0:00:01
#      ----------------------------------       2.2/2.5 MB 3.0 MB/s eta 0:00:01
#      ------------------------------------     2.3/2.5 MB 3.0 MB/s eta 0:00:01
#      --------------------------------------   2.4/2.5 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=3.10 in c:\penvs\llm\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\penvs\llm\lib\site-packages (from bokeh<2.5.0,>=2.4.0->panel) (6.3.1)
# Requirement already satisfied: colorama in c:\penvs\llm\lib\site-packages (from tqdm>=4.48.0->panel) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\penvs\llm\lib\site-packages (from bleach->panel) (1.16.0)
# Requirement already satisfied: webencodings in c:\penvs\llm\lib\site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\penvs\llm\lib\site-packages (from markdown->panel) (6.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\penvs\llm\lib\site-packages (from requests->panel) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\penvs\llm\lib\site-packages (from requests->panel) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\penvs\llm\lib\site-packages (from requests->panel) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\penvs\llm\lib\site-packages (from requests->panel) (2023.5.7)
# Requirement already satisfied: zipp>=0.5 in c:\penvs\llm\lib\site-packages (from importlib-metadata>=4.4->markdown->panel) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\penvs\llm\lib\site-packages (from Jinja2>=2.9->bokeh<2.5.0,>=2.4.0->panel) (2.1.2)
# Installing collected packages: pillow, param, numpy, pyviz-comms, pyct, markdown, bokeh, panel
# Successfully installed bokeh-2.4.3 markdown-3.4.3 numpy-1.24.3 panel-0.14.4 param-1.13.0 pillow-9.5.0 pyct-0.5.0 pyviz-comms-2.2.1

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display 

context = [ {'role':'system', 'content':"""
You are OrderBot, an automated service to collect orders for a pizza restaurant. \
You first greet the customer, then collects the order, \
and then asks if it's a pickup or delivery. \
You wait to collect the entire order, then summarize it and check for a final \
time if the customer wants to add anything else. \
If it's a delivery, you ask for an address. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very conversational friendly style. \
The menu includes \
pepperoni pizza  12.95, 10.00, 7.00 \
cheese pizza   10.95, 9.25, 6.50 \
eggplant pizza   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
greek salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
sausage 3.00 \
canadian bacon 3.50 \
AI sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
bottled water 5.00 \
"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <pre>Traceback (most recent call last):
#   File &quot;C:\penvs\llm\lib\site-packages\urllib3\connectionpool.py&quot;, line 790, in urlopen
#     response = self._make_request(
#   File &quot;C:\penvs\llm\lib\site-packages\urllib3\connectionpool.py&quot;, line 536, in _make_request
#     response = conn.getresponse()
#   File &quot;C:\penvs\llm\lib\site-packages\urllib3\connection.py&quot;, line 454, in getresponse
#     httplib_response = super().getresponse()
#   File &quot;C:\Python\Python39\lib\http\client.py&quot;, line 1377, in getresponse
#     response.begin()
#   File &quot;C:\Python\Python39\lib\http\client.py&quot;, line 320, in begin
#     version, status, reason = self._read_status()
#   File &quot;C:\Python\Python39\lib\http\client.py&quot;, line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), &quot;iso-8859-1&quot;)
#   File &quot;C:\Python\Python39\lib\socket.py&quot;, line 704, in readinto
#     return self._sock.recv_into(b)
#   File &quot;C:\Python\Python39\lib\ssl.py&quot;, line 1242, in recv_into
#     return self.read(nbytes, buffer)
#   File &quot;C:\Python\Python39\lib\ssl.py&quot;, line 1100, in read
#     return self._sslobj.read(len, buffer)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File &quot;C:\penvs\llm\lib\site-packages\requests\adapters.py&quot;, line 486, in send
#     resp = conn.urlopen(
#   File &quot;C:\penvs\llm\lib\site-packages\urllib3\connectionpool.py&quot;, line 844, in urlopen
#     retries = retries.increment(
#   File &quot;C:\penvs\llm\lib\site-packages\urllib3\util\retry.py&quot;, line 470, in increment
#     raise reraise(type(error), error, _stacktrace)
#   File &quot;C:\penvs\llm\lib\site-packages\urllib3\util\util.py&quot;, line 38, in reraise
#     raise value.with_traceback(tb)
#   File &quot;C:\penvs\llm\lib\site-packages\urllib3\connectionpool.py&quot;, line 790, in urlopen
#     response = self._make_request(
#   File &quot;C:\penvs\llm\lib\site-packages\urllib3\connectionpool.py&quot;, line 536, in _make_request
#     response = conn.getresponse()
#   File &quot;C:\penvs\llm\lib\site-packages\urllib3\connection.py&quot;, line 454, in getresponse
#     httplib_response = super().getresponse()
#   File &quot;C:\Python\Python39\lib\http\client.py&quot;, line 1377, in getresponse
#     response.begin()
#   File &quot;C:\Python\Python39\lib\http\client.py&quot;, line 320, in begin
#     version, status, reason = self._read_status()
#   File &quot;C:\Python\Python39\lib\http\client.py&quot;, line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), &quot;iso-8859-1&quot;)
#   File &quot;C:\Python\Python39\lib\socket.py&quot;, line 704, in readinto
#     return self._sock.recv_into(b)
#   File &quot;C:\Python\Python39\lib\ssl.py&quot;, line 1242, in recv_into
#     return self.read(nbytes, buffer)
#   File &quot;C:\Python\Python39\lib\ssl.py&quot;, line 1100, in read
#     return self._sslobj.read(len, buffer)
# urllib3.exceptions.ProtocolError: (&#x27;Connection aborted.&#x27;, ConnectionResetError(10054, &#x27;An existing connection was forcibly closed by the remote host&#x27;, None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File &quot;C:\penvs\llm\lib\site-packages\openai\api_requestor.py&quot;, line 520, in request_raw
#     result = _thread_context.session.request(
#   File &quot;C:\penvs\llm\lib\site-packages\requests\sessions.py&quot;, line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File &quot;C:\penvs\llm\lib\site-packages\requests\sessions.py&quot;, line 701, in send
#     r = adapter.send(request, **kwargs)
#   File &quot;C:\penvs\llm\lib\site-packages\requests\adapters.py&quot;, line 501, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: (&#x27;Connection aborted.&#x27;, ConnectionResetError(10054, &#x27;An existing connection was forcibly closed by the remote host&#x27;, None, 10054, None))
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File &quot;C:\Users\rbandyopadhyay\AppData\Local\Temp\ipykernel_13172\195219520.py&quot;, line 18, in get_completion_from_messages
#     response = openai.ChatCompletion.create(
#   File &quot;C:\penvs\llm\lib\site-packages\openai\api_resources\chat_completion.py&quot;, line 25, in create
#     return super().create(*args, **kwargs)
#   File &quot;C:\penvs\llm\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py&quot;, line 153, in create
#     response, _, api_key = requestor.request(
#   File &quot;C:\penvs\llm\lib\site-packages\openai\api_requestor.py&quot;, line 220, in request
#     result = self.request_raw(
#   File &quot;C:\penvs\llm\lib\site-packages\openai\api_requestor.py&quot;, line 533, in request_raw
#     raise error.APIConnectionError(
# openai.error.APIConnectionError: Error communicating with OpenAI: (&#x27;Connection aborted.&#x27;, ConnectionResetError(10054, &#x27;An existing connection was forcibly closed by the remote host&#x27;, None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File &quot;C:\penvs\llm\lib\site-packages\pyviz_comms\__init__.py&quot;, line 346, in _handle_msg
#     self._on_msg(msg)
#   File &quot;C:\penvs\llm\lib\site-packages\panel\viewable.py&quot;, line 297, in _on_msg
#     patch.apply_to_document(doc, comm.id if comm else None)
#   File &quot;C:\penvs\llm\lib\site-packages\bokeh\protocol\messages\patch_doc.py&quot;, line 115, in apply_to_document
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.content, setter))
#   File &quot;C:\penvs\llm\lib\site-packages\bokeh\document\callbacks.py&quot;, line 408, in invoke_with_curdoc
#     return f()
#   File &quot;C:\penvs\llm\lib\site-packages\bokeh\protocol\messages\patch_doc.py&quot;, line 115, in &lt;lambda&gt;
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.content, setter))
#   File &quot;C:\penvs\llm\lib\site-packages\bokeh\document\document.py&quot;, line 391, in apply_json_patch
#     DocumentPatchedEvent.handle_json(self, event_json, references, setter)
#   File &quot;C:\penvs\llm\lib\site-packages\bokeh\document\events.py&quot;, line 259, in handle_json
#     handler(doc, event_json, references, setter)
#   File &quot;C:\penvs\llm\lib\site-packages\bokeh\document\events.py&quot;, line 300, in _handle_json
#     cb(event_json[&quot;msg_data&quot;])
#   File &quot;C:\penvs\llm\lib\site-packages\bokeh\document\callbacks.py&quot;, line 355, in trigger_json_event
#     model._trigger_event(event)
#   File &quot;C:\penvs\llm\lib\site-packages\bokeh\util\callback_manager.py&quot;, line 119, in _trigger_event
#     self.document.callbacks.notify_event(cast(Model, self), event, invoke)
#   File &quot;C:\penvs\llm\lib\site-packages\bokeh\document\callbacks.py&quot;, line 247, in notify_event
#     invoke_with_curdoc(doc, callback_invoker)
#   File &quot;C:\penvs\llm\lib\site-packages\bokeh\document\callbacks.py&quot;, line 408, in invoke_with_curdoc
#     return f()
#   File &quot;C:\penvs\llm\lib\site-packages\bokeh\util\callback_manager.py&quot;, line 115, in invoke
#     cast(EventCallbackWithEvent, callback)(event)
#   File &quot;C:\penvs\llm\lib\site-packages\panel\reactive.py&quot;, line 413, in _comm_event
#     state._handle_exception(e)
#   File &quot;C:\penvs\llm\lib\site-packages\panel\io\state.py&quot;, line 408, in _handle_exception
#     raise exception
#   File &quot;C:\penvs\llm\lib\site-packages\panel\reactive.py&quot;, line 411, in _comm_event
#     self._process_bokeh_event(doc, event)
#   File &quot;C:\penvs\llm\lib\site-packages\panel\reactive.py&quot;, line 348, in _process_bokeh_event
#     self._process_event(event)
#   File &quot;C:\penvs\llm\lib\site-packages\panel\widgets\button.py&quot;, line 183, in _process_event
#     self.param.trigger(&#x27;value&#x27;)
#   File &quot;C:\penvs\llm\lib\site-packages\
# Column
#     [0] TextInput(placeholder='Enter text here…')
#     [1] Row
#         [0] Button(name='Chat!')
#     [2] ParamFunction(function, _pane=Column, height=300, loading_indicator=True)

# %%
messages =  context.copy()
messages.append(
{'role':'system', 'content':'create a json summary of the previous food order. Itemize the price for each item\
 The fields should be 1) pizza, include size 2) list of toppings 3) list of drinks, include size   4) list of sides include size  5)total price '},    
)
 #The fields should be 1) pizza, price 2) list of toppings 3) list of drinks, include size include price  4) list of sides include size include price, 5)total price '},    

response = get_completion_from_messages(messages, temperature=0)
print(response)
# Out:
# Here's a JSON summary of the previous food order:
#
# ```
# {
#   "pizza": {
#     "type": "cheese",
#     "size": "small",
#     "price": 6.5
#   },
#   "toppings": [],
#   "drinks": [
#     {
#       "type": "coke",
#       "size": "regular",
#       "price": 3
#     }
#   ],
#   "sides": [],
#   "total_price": 9.5
# }
# ```
#
# Note that there are no toppings or sides in this order, but those fields are included in the JSON summary for completeness.

# %%
import re

total_content_length = sum([len(re.split("\s", m['content'])) for m in messages])
print(f"Total content lentgth = {total_content_length} tokens")
# Out:
# Total content lentgth = 421 tokens
